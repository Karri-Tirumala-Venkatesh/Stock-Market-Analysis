# %%
import yfinance as yf
import pandas as pd

# Define stock symbol for NSE
ticker = "RELIANCE.NS"

# Fetch minute-wise data for the last 1 day
df = yf.download(ticker, period="1d", interval="1m")

# Check if the index is already timezone-aware
if not df.index.tz:
    # If not, localize to UTC
    df.index = df.index.tz_localize('UTC')

# Convert the index to Indian Standard Time (IST)
df.index = df.index.tz_convert('Asia/Kolkata')

df
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                            Close         High          Low         Open  \
# Ticker                     RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS
# Datetime
# 2025-03-12 09:15:00+05:30  1257.300049  1260.849976  1255.599976  1255.599976
# 2025-03-12 09:16:00+05:30  1257.699951  1258.050049  1255.849976  1257.099976
# 2025-03-12 09:17:00+05:30  1258.800049  1259.400024  1257.000000  1257.699951
# 2025-03-12 09:18:00+05:30  1259.300049  1259.849976  1258.050049  1258.550049
# 2025-03-12 09:19:00+05:30  1258.400024  1260.750000  1258.300049  1259.199951
# ...                                ...          ...          ...          ...
# 2025-03-12 15:25:00+05:30  1256.099976  1257.000000  1256.050049  1256.949951
# 2025-03-12 15:26:00+05:30  1256.400024  1256.449951  1256.000000  1256.099976
# 2025-03-12 15:27:00+05:30  1256.500000  1257.300049  1256.050049  1256.400024
# 2025-03-12 15:28:00+05:30  1256.199951  1256.550049  1256.099976  1256.550049
# 2025-03-12 15:29:00+05:30  1256.000000  1256.199951  1255.500000  1256.099976
#
# Price                          Volume
# Ticker                    RELIANCE.NS
# Datetime
# 2025-03-12 09:15:00+05:30           0
# 2025-03-12 09:16:00+05:30      111216
# 2025-03-12 09:17:00+05:30       98288
# 2025-03-12 09:18:00+05:30       86064
# 2025-03-12 09:19:00+05:30      151129
# ...                               ...
# 2025-03-12 15:25:00+05:30      130011
# 2025-03-12 15:26:00+05:30       84387
# 2025-03-12 15:27:00+05:30      164784
# 2025-03-12 15:28:00+05:30       51283
# 2025-03-12 15:29:00+05:30       33361
#
# [374 rows x 5 columns]

# %%
# Convert df to a csv file which can be downloaded
from google.colab import files
df.to_csv('reliance.csv')
files.download('reliance.csv')
